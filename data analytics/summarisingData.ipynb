# %%
import pandas as pd

# %%
df = pd.read_excel('Canada.xlsx', sheet_name = "Canada by Citizenship", skiprows=range(20), skipfooter=2)
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.rename(columns={ 'OdName' : 'Country', 'AreaName' : 'Continent' }, inplace=True)
df.drop(columns=['Type', 'Coverage', 'AREA', 'REG', 'DEV'], inplace=True)

# %%
# to remove unnamed columns
df = df[df.columns[:-8]]

# %%
df[df['Country'] == 'India']
# Out:
#    Country Continent        RegName             DevName  1980  1981  1982  \
# 79   India      Asia  Southern Asia  Developing regions  8880  8670  8147
#
#     1983  1984  1985  ...   1996   1997   1998   1999   2000   2001   2002  \
# 79  7338  5704  4211  ...  23859  22268  17241  18974  28572  31223  31889
#
#      2003   2004   2005
# 79  27155  28235  36210
#
# [1 rows x 30 columns]

# %%
df.Country
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: Country, Length: 195, dtype: object

# %%
df.Country.unique().size
# Out:
# 195

# %%
# creating a new index
df.set_index('Country', inplace=True)

# %%
df.head()
# Out:
#                Continent          RegName             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  1996  1997  1998  1999  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  2212  2555  1999  2395
# Albania            0     0     0     0     1  ...   113   307   574  1264
# Algeria           71    69    63    44    69  ...  2054  1842  2292  2389
# American Samoa     0     0     0     0     0  ...     0     0     0     0
# Andorra            0     0     0     0     2  ...     0     0     2     0
#
# ...

# %%
df.columns
# Out:
# Index(['Continent',   'RegName',   'DevName',        1980,        1981,
#               1982,        1983,        1984,        1985,        1986,
#               1987,        1988,        1989,        1990,        1991,
#               1992,        1993,        1994,        1995,        1996,
#               1997,        1998,        1999,        2000,        2001,
#               2002,        2003,        2004,        2005],
#       dtype='object')

# %%
df.loc[ 'India' ]
# Out:
# Continent                  Asia
# RegName           Southern Asia
# DevName      Developing regions
# 1980                       8880
# 1981                       8670
# 1982                       8147
# 1983                       7338
# 1984                       5704
# 1985                       4211
# 1986                       7150
# 1987                      10189
# 1988                      11522
# 1989                      10343
# 1990                      12041
# 1991                      13734
# 1992                      13673
# 1993                      21496
# 1994                      18620
# 1995                      18489
# 1996                      23859
# 1997                      22268
# 1998                      17241
# 1999                      18974
# 2000                      28572
# 2001                      31223
# 2002                      31889
# 2003                      27155
# 2004                      28235
# 2005                      36210
# ...

# %%
df.loc[ 'India', [2005] ]
# Out:
# 2005    36210
# Name: India, dtype: object

# %%
years = list(range(1980, 2005))

# %%
df.loc[ 'India', years ]
# Out:
# 1980     8880
# 1981     8670
# 1982     8147
# 1983     7338
# 1984     5704
# 1985     4211
# 1986     7150
# 1987    10189
# 1988    11522
# 1989    10343
# 1990    12041
# 1991    13734
# 1992    13673
# 1993    21496
# 1994    18620
# 1995    18489
# 1996    23859
# 1997    22268
# 1998    17241
# 1999    18974
# 2000    28572
# 2001    31223
# 2002    31889
# 2003    27155
# 2004    28235
# Name: India, dtype: object

# %%
df.groupby('Continent').count()
# Out:
#                                  RegName  DevName  1980  1981  1982  1983  \
# Continent
# Africa                                54       54    54    54    54    54
# Asia                                  49       49    49    49    49    49
# Europe                                43       43    43    43    43    43
# Latin America and the Caribbean       33       33    33    33    33    33
# Northern America                       2        2     2     2     2     2
# Oceania                               14       14    14    14    14    14
#
#                                  1984  1985  1986  1987  ...  1996  1997  \
# Continent                                                ...
# Africa                             54    54    54    54  ...    54    54
# Asia                               49    49    49    49  ...    49    49
# Europe                             43    43    43    43  ...    43    43
# Latin America and the Caribbean    33    33    33    33  ...    33    33
# ...

# %%
df.groupby('Continent').sum()
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                   1986   1987   1988   1989  ...    1996  \
# Continent                                                    ...
# Africa                            3782   7494   7552   9894  ...   15700
# Asia                             28739  43203  47454  60256  ...  103030
# Europe                           24370  46698  54726  60893  ...   55642
# Latin America and the Caribbean  21179  28471  21924  25060  ...   18645
# ...

# %%
df.groupby('Continent').min()
# Out:
#                                                    RegName  \
# Continent
# Africa                                      Eastern Africa
# Asia                                          Central Asia
# Europe                                      Eastern Europe
# Latin America and the Caribbean                  Caribbean
# Northern America                          Northern America
# Oceania                          Australia and New Zealand
#
#                                             DevName  1980  1981  1982  1983  \
# Continent
# Africa                           Developing regions     0     0     0     0
# Asia                              Developed regions     0     0     0     0
# Europe                            Developed regions     0     0     0     0
# Latin America and the Caribbean  Developing regions     0     0     0     0
# Northern America                  Developed regions     0     0     0     0
# ...

# %%
df.groupby('Continent', as_index=False).min()
# Out:
#                          Continent                    RegName  \
# 0                           Africa             Eastern Africa
# 1                             Asia               Central Asia
# 2                           Europe             Eastern Europe
# 3  Latin America and the Caribbean                  Caribbean
# 4                 Northern America           Northern America
# 5                          Oceania  Australia and New Zealand
#
#               DevName  1980  1981  1982  1983  1984  1985  1986  ...  1996  \
# 0  Developing regions     0     0     0     0     0     0     0  ...     0
# 1   Developed regions     0     0     0     0     0     0     0  ...     0
# 2   Developed regions     0     0     0     0     0     0     0  ...     0
# 3  Developing regions     0     0     0     0     5    16     7  ...    18
# 4   Developed regions     0     0     0     0     0     0     0  ...     1
# 5   Developed regions     0     0     0     0     0     0     0  ...     0
#
# ...

# %%
df[df['Continent'].str.startswith('A') ]
# Out:
#                Continent             RegName             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Algeria           Africa     Northern Africa  Developing regions    80    67
# Angola            Africa       Middle Africa  Developing regions     1     3
# Armenia             Asia        Western Asia  Developing regions     0     0
# Azerbaijan          Asia        Western Asia  Developing regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
selCont = ['Asia', "Europe"]

# %%
df[df['Continent'].isin(selCont)]
# Out:
#                                                    Continent  \
# Country
# Afghanistan                                             Asia
# Albania                                               Europe
# Andorra                                               Europe
# Armenia                                                 Asia
# Austria                                               Europe
# ...                                                      ...
# United Arab Emirates                                    Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Uzbekistan                                              Asia
# Viet Nam                                                Asia
# Yemen                                                   Asia
#
#                                                                RegName  \
# Country
# Afghanistan                                              Southern Asia
# ...

# %%
df[(df['Continent'].isin(selCont)) & (df['Continent'].str.startswith('A')) ]
# Out:
#                                                Continent             RegName  \
# Country
# Afghanistan                                         Asia       Southern Asia
# Armenia                                             Asia        Western Asia
# Azerbaijan                                          Asia        Western Asia
# Bahrain                                             Asia        Western Asia
# Bangladesh                                          Asia       Southern Asia
# Bhutan                                              Asia       Southern Asia
# Brunei Darussalam                                   Asia  South-Eastern Asia
# Cambodia                                            Asia  South-Eastern Asia
# China                                               Asia        Eastern Asia
# China, Hong Kong Special Administrative Region      Asia        Eastern Asia
# China, Macao Special Administrative Region          Asia        Eastern Asia
# ...

# %%
df.groupby('AreaName', as_index=False).count().set_index('OdName')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17132/657587748.py in <module>
# ----> 1 df.groupby('AreaName', as_index=False).count().set_index('OdName')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...
